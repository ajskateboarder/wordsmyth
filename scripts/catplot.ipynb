# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

df = pd.read_pickle("../data/reviews.pkl")
sns.set(rc={'axes.facecolor': 'black', 'figure.facecolor': 'black', 'xtick.color': 'white', 'ytick.color': 'white', 'grid.color': '#303030'})

g = sns.catplot(df, x="overall", y="rating", palette="pastel", hue="overall") \
        .set_axis_labels("Actual rating", "Predicted rating") \
        .set(xlim=(-1, 5), ylim=(0, 6))
g.savefig("../media/catplot.png")
