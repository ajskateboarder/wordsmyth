# %%
import pandas as pd

df = pd.read_csv('final.csv')
df.head()
# Out:
#                                              content       emoji  position  \
# 0                 I know we just met, but I love you  :thumbsup:         0
# 1  I recently followed this video and now Twilio ...      :eyes:         0
# 2                                     Bla bla bla...  :thumbsup:         4
# 3  Thanks Craig. I learnt sooo much. U r God sent...  :thumbsup:         1
# 4  I am confused with the Twlio segment. Wnen I p...  :confused:         2
#
#                                               emojis  matches sentiment.flair  \
# 0  [':thumbsup:', ':rage:', ':angry:', ':pray:', ...     True             pos
# 1  [':eyes:', ':skull:', ':flushed:', ':neutral_f...    False             pos
# 2  [':wink:', ':v:', ':smile:', ':blush:', ':thum...    False             neg
# 3  [':rage:', ':thumbsup:', ':angry:', ':wink:', ...     True             pos
# 4  [':rage:', ':angry:', ':confused:', ':thumbsup...     True             neg
#
#   sentiment.map
# 0           pos
# ...

# %%
df.query("matches == False")[["content", "emoji", "sentiment.map", "sentiment.flair"]]
# Out:
#                                               content       emoji  \
# 1   I recently followed this video and now Twilio ...      :eyes:
# 2                                      Bla bla bla...  :thumbsup:
# 5                  Hey, thanks for the tip in 0:35:45      :eyes:
# 6                        https://youtu.be/EBOq1xr0ieo  :thumbsup:
# 7   thanks to the name above ☝️☝️👆👆 who help me wi...  :confused:
# 8                         Need to import humor too ;)  :thumbsup:
# 9   Not me yelling 'P' in my house..... love this ...  :confused:
# 10  Man, I was looking for a video like this for a...  :confused:
# 11  🇬🇧Strongly recommending Mr.Edward Richardson f...      :eyes:
# 15                      This video is amazing, thanks  :confused:
# 16  do you fancy creating a video about exploiting...  :thumbsup:
# 17  Since YT got rid of the so helpful like-dislik...  :thumbsup:
# 18  Absolute life saver! Thank you so much for mak...  :confused:
# ...

# %%
df.query("matches == True")[["content", "emoji", "sentiment.map", "sentiment.flair"]]
# Out:
#                                               content       emoji  \
# 0                  I know we just met, but I love you  :thumbsup:
# 3   Thanks Craig. I learnt sooo much. U r God sent...  :thumbsup:
# 4   I am confused with the Twlio segment. Wnen I p...  :confused:
# 12  I seriously enjoy your teaching method and I a...  :thumbsup:
# 13                           gracias, saludos de Peru  :thumbsup:
# 14  Here I am, employed as a developer, watching a...  :thumbsup:
# 19     You are a genius, you helped me do my work...!  :thumbsup:
# 20  This is the first tutorial that I’m watching w...  :thumbsup:
# 22          at 37:00 cross walk captcha solving guide  :thumbsup:
# 25  Is that a GUARIA MORADA? I'm from Costa Rica a...  :thumbsup:
# 27  How can we add a number counter to a website w...  :confused:
# 30                                              18:40  :thumbsup:
# 31                                   Learning by Crio  :thumbsup:
# ...
